# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Question 9
with open('e:/EXOS ANALYSE DONNEES S1/island-index.csv', encoding= 'utf-8') as file3: 
    contenu = pd.read_csv(file3)
    # Afficher le DataFrame pour vérifier son contenu
    contenu = pd.DataFrame(contenu)
print(contenu)
# Définir les intervalles pour la catégorisation
bins = [0, 10, 25, 50, 100, 2500, 5000, 10000, float('inf')]
labels = ['0-10', '10-25', '25-50', '50-100', '100-2500', '2500-5000', '5000-10000', '≥10000']

# Créer une nouvelle colonne avec les catégories
contenu['Catégorie_Surface'] = pd.cut(contenu['Surface (km²)'], 
                                     bins=bins, 
                                     labels=labels, 
                                     right=True)

# Compter le nombre d'îles dans chaque catégorie
comptage = contenu['Catégorie_Surface'].value_counts().sort_index()

# Afficher les résultats
print("\nNombre d'îles par catégorie de surface :")
print(comptage)

# Créer un graphique à barres pour visualiser la distribution
plt.figure(figsize=(12, 6))
comptage.plot(kind='bar')
plt.title("Distribution des îles par catégorie de surface")
plt.xlabel("Catégorie de surface (km²)")
plt.ylabel("Nombre d'îles")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\stell\AppData\Local\Temp\ipykernel_4056\3516261927.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   contenu = pd.read_csv(file3)
#                   Type                        Identifiant Toponyme Code ISO 1  \
# ILE NORMALE          1                       Aruba Island      ABW        NaN
# ILE NORMALE          3             Baia dos Tigres Island      AGO        NaN
# ILE NORMALE          5                                NaN      AGO        NaN
# ILE NORMALE          6                                NaN      AGO        NaN
# ILE NORMALE          7                                NaN      AGO        NaN
# ...                ...                                ...      ...        ...
# ILE PARTITIONNEE     7                              Timor      IDN        TLS
# ILE PARTITIONNEE     8  Martin Garcia / Timoteo Dominguez      ARG        CHL
# ILE PARTITIONNEE     9                            Sebatik      IDN        MYS
# ILE PARTITIONNEE    10                             Usedom      POL        DEU
# ILE PARTITIONNEE    11                       Saint-Martin      ANT        GLP
#
#                  Code ISO 2 Code ISO 3  Trait de côte (km)  Surface (km²)  \
# ILE NORMALE             NaN        NaN          105.706524     181.938366
# ILE NORMALE             NaN        NaN           70.472444      88.570958
# ILE NORMALE             NaN        NaN           52.638245      26.792477
# ILE NORMALE             NaN        NaN           12.593973       2.988454
# ILE NORMALE             NaN        NaN            2.249531       0.090183
# ...                     ...        ...                 ...            ...
# ILE PARTITIONNEE        TLS          -         1302.747132   28614.462241
# ILE PARTITIONNEE          -          -           10.861885       3.964517
# ILE PARTITIONNEE          -          -          100.990954     438.677403
# ILE PARTITIONNEE          -          -          305.370290     418.019026
# ILE PARTITIONNEE          -          -           95.800586      92.137438
#
#                     Latitude  Longitude
# ILE NORMALE       -69.970276  12.509315
# ILE NORMALE        11.704911 -16.595546
# ILE NORMALE        12.299087  -6.118821
# ILE NORMALE        12.291456  -6.155205
# ILE NORMALE        12.341880 -14.393714
# ...                      ...        ...
# ILE PARTITIONNEE  124.853273  -9.270434
# ILE PARTITIONNEE   14.097525  53.938803
# ILE PARTITIONNEE  117.790302   4.154421
# ILE PARTITIONNEE  -58.252983 -34.177514
# ILE PARTITIONNEE  -63.062682  18.058222
#
# [84219 rows x 10 columns]
#
# Nombre d'îles par catégorie de surface :
# Catégorie_Surface
# 0-10          78423
# 10-25          2327
# 25-50          1164
# 50-100          788
# 100-2500       1346
# 2500-5000        60
# 5000-10000       40
# ≥10000           71
# Name: count, dtype: int64
